# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data.csv')
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
data.shape
# Out:
# (398, 9)

# %%
data.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
a= data['horsepower'].isna().sum()
print(a)
# Out:
# 6

# %%
data.isnull().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Length: 398, dtype: bool

# %%
data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
df=data.fillna(data["acceleration"].mean())

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
#Returns unique value
df['horsepower'].unique()
# Out:
# array([130.        , 165.        , 150.        , 140.        ,
#        198.        , 220.        , 215.        , 225.        ,
#        190.        , 170.        , 160.        ,  95.        ,
#         97.        ,  85.        ,  88.        ,  46.        ,
#         87.        ,  90.        , 113.        , 200.        ,
#        210.        , 193.        ,  15.56809045, 100.        ,
#        105.        , 175.        , 153.        , 180.        ,
#        110.        ,  72.        ,  86.        ,  70.        ,
#         76.        ,  65.        ,  69.        ,  60.        ,
#         80.        ,  54.        , 208.        , 155.        ,
#        112.        ,  92.        , 145.        , 137.        ,
#        158.        , 167.        ,  94.        , 107.        ,
#        230.        ,  49.        ,  75.        ,  91.        ,
#        122.        ,  67.        ,  83.        ,  78.        ,
#         52.        ,  61.        ,  93.        , 148.        ,
# ...

# %%
plt.plot(data['horsepower'])

# %%
plt.hist(data['horsepower'],bins=20)
# Out:
# (array([13., 14., 55., 40., 67., 53., 40., 10.,  8., 11., 18., 29.,  7.,
#          6., 10.,  4.,  3.,  2.,  4.,  4.]),
#  array([ 46. ,  55.2,  64.4,  73.6,  82.8,  92. , 101.2, 110.4, 119.6,
#         128.8, 138. , 147.2, 156.4, 165.6, 174.8, 184. , 193.2, 202.4,
#         211.6, 220.8, 230. ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(data['cylinders'])
# Out:
# (array([  4.,   0., 204.,   0.,   3.,   0.,  84.,   0.,   0., 103.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(data[['horsepower','displacement']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e37f8cf8970>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e37f8cf8e50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e37f8cf8670>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7e37f8cf9450>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7e37f8cf9750>,
# ...
#  'means': []}

# %%
sns.violinplot(x=df['displacement'])
# Out:
# <Axes: xlabel='displacement'>

# %%
plt.boxplot(df['acceleration'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x77092b79a470>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x77092b79aa70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x77092b79a170>],
#  'medians': [<matplotlib.lines.Line2D at 0x77092b79b070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x77092b79afb0>],
#  'means': []}

# %%
df2 =pd.DataFrame(df)

# %%
sns.boxplot(x=df2['acceleration'])
# Out:
# <Axes: xlabel='acceleration'>

# %%
lower = df2['acceleration'].quantile(0.05)
upper = df2['acceleration'].quantile(0.95)

df2['acceleration']=np.where(df2['acceleration']<lower,lower,df2['acceleration'])
df2['acceleration']=np.where(df2['acceleration']>upper,upper,df2['acceleration'])

# %%
sns.boxplot(x=df2['acceleration'])
# Out:
# <Axes: xlabel='acceleration'>

# %%
print(df2.dtypes)
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
sns.heatmap(df2.select_dtypes(include=['number']).corr(), annot=True, cmap='cool')
# Out:
# <Axes: >

# %%
sns.heatmap(df2.select_dtypes(include=['number']).corr(),annot=True,cmap='coolwar')
# Out:
# <Axes: >
